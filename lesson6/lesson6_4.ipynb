# %%
import yfinance as yf
data = yf.download('006208.TW')
data

# %%
Taiwan = yf.download('006208.TW')
all_data = Taiwan.to_dict(orient='index')
for key,value in all_data.items():
    print(key)
    print(type(key))
    print(value)
    print("=========")
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2012-06-22 00:00:00+00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# {('Adj Close', '006208.TW'): 21.1807861328125, ('Close', '006208.TW'): 30.0, ('High', '006208.TW'): 30.0, ('Low', '006208.TW'): 30.0, ('Open', '006208.TW'): 30.0, ('Volume', '006208.TW'): 0}
# ...
# 2012-06-25 00:00:00+00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# {('Adj Close', '006208.TW'): 21.1807861328125, ('Close', '006208.TW'): 30.0, ('High', '006208.TW'): 30.0, ('Low', '006208.TW'): 30.0, ('Open', '006208.TW'): 30.0, ('Volume', '006208.TW'): 0}
# ...
# 2012-06-26 00:00:00+00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# {('Adj Close', '006208.TW'): 21.1807861328125, ('Close', '006208.TW'): 30.0, ('High', '006208.TW'): 30.0, ('Low', '006208.TW'): 30.0, ('Open', '006208.TW'): 30.0, ('Volume', '006208.TW'): 0}
# ...
# 2012-06-27 00:00:00+00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# ...
